# %% [markdown]
# 1. récupération des données temps réel de l'ensemble des cryptomonnaies et monnaies

# %%
#TODO FNJ Utiliser le ENDPONT n°8
 
import requests
from requests import get
from pprint import pprint
import pandas as pd
# Define API key here
API_KEY = 'FB1FD030-3EF4-4D84-9306-7A327A708533'
new_API_KEY = "3A5CEF16-7C99-4467-92EC-EA9431EAEDDE"
# Define endpoint url here
url = "https://rest.coinapi.io/v1/exchangerate/EUR?apikey={}&invert=true&output_format=csv".format(API_KEY)

print(url)

df = pd.read_csv(url, sep=';', parse_dates=True)

df.info()
# Out:
# https://rest.coinapi.io/v1/exchangerate/EUR?apikey=FB1FD030-3EF4-4D84-9306-7A327A708533&invert=true&output_format=csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4354 entries, 0 to 4353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time            4354 non-null   object
#  1   asset_id_quote  4354 non-null   object
#  2   rate            4354 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 102.2+ KB

# %%
df.head()
# Out:
#                            time asset_id_quote      rate
# 0  2023-07-18T22:10:14.0000000Z           $PAC  0.000066
# 1  2023-07-18T22:10:14.0000000Z             00  0.079610
# 2  2023-07-18T22:10:14.0000000Z       1000PEPE  0.000678
# 3  2023-07-18T22:10:14.0000000Z       1000SHIB  0.003439
# 4  2023-07-18T22:10:14.0000000Z         1EARTH  0.001717

# %% [markdown]
# 2. récupération des données temps réel d'une seule cryptomonnaie

# %%
url = 'https://rest.coinapi.io/v1/exchangerate/BTC/USD'
headers = {'X-CoinAPI-Key' : 'FB1FD030-3EF4-4D84-9306-7A327A708533'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# ('{\n'
#  '  "time": "2023-07-09T19:07:56.0000000Z",\n'
#  '  "asset_id_base": "BTC",\n'
#  '  "asset_id_quote": "USD",\n'
#  '  "rate": 30228.38893863893906963702902\n'
#  '}')

# %% [markdown]
# 3. Récupération des données historiques d'une seule cryptomonnaie

# %%
url = 'https://rest.coinapi.io/v1/exchangerate/BTC/USD/history?period_id=1MIN&time_start=2023-06-01T00:00:00&time_end=2023-07-01T00:00:00'
headers = {'X-CoinAPI-Key' : 'FB1FD030-3EF4-4D84-9306-7A327A708533'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# ('[\n'
#  '  {\n'
#  '    "time_period_start": "2023-06-01T00:00:00.0000000Z",\n'
#  '    "time_period_end": "2023-06-01T00:01:00.0000000Z",\n'
#  '    "time_open": "2023-06-01T00:00:00.0000000Z",\n'
#  '    "time_close": "2023-06-01T00:00:00.0000000Z",\n'
#  '    "rate_open": 27216.498604819182,\n'
#  '    "rate_high": 27216.498604819182,\n'
#  '    "rate_low": 27216.498604819182,\n'
#  '    "rate_close": 27216.498604819182\n'
#  '  },\n'
#  '  {\n'
#  '    "time_period_start": "2023-06-01T00:01:00.0000000Z",\n'
#  '    "time_period_end": "2023-06-01T00:02:00.0000000Z",\n'
#  '    "time_open": "2023-06-01T00:01:00.0000000Z",\n'
#  '    "time_close": "2023-06-01T00:01:00.0000000Z",\n'
#  '    "rate_open": 27221.256208091185,\n'
#  '    "rate_high": 27221.256208091185,\n'
#  '    "rate_low": 27221.256208091185,\n'
#  '    "rate_close": 27221.256208091185\n'
#  '  },\n'
#  '  {\n'
#  '    "time_period_start": "2023-06-01T00:02:00.0000000Z",\n'
# ...

# %% [markdown]
# 4. Metriques des diffrentes échanges

# %%
import requests
url = 'https://rest.coinapi.io/v1/metrics/exchange/DERIBIT/current'
headers = {'X-CoinAPI-Key' : 'FB1FD030-3EF4-4D84-9306-7A327A708533'}
response = requests.get(url, headers=headers)


pprint(response.text)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  '    "entry_time": "2023-07-13T07:43:18.1263270Z",\n'
#  '    "recv_time": "2023-07-13T07:43:18.0290000Z",\n'
#  '    "exchange_id": "DERIBIT",\n'
#  '    "symbol_id": "DERIBIT_OPT_BTC_USD_230929_20000_P",\n'
#  '    "metric_id": "DERIVATIVES_OPEN_INTEREST",\n'
#  '    "value_decimal": 1287.4\n'
#  '  },\n'
#  '  {\n'
#  '    "entry_time": "2023-07-13T15:15:28.9719319Z",\n'
#  '    "recv_time": "2023-07-13T15:15:28.7350000Z",\n'
#  '    "exchange_id": "DERIBIT",\n'
#  '    "symbol_id": "DERIBIT_OPT_BTC_USD_230728_34000_C",\n'
#  '    "metric_id": "DERIVATIVES_INDEX_PRICE",\n'
#  '    "value_decimal": 30567.81\n'
#  '  },\n'
#  '  {\n'
#  '    "entry_time": "2023-07-13T15:15:27.6432088Z",\n'
#  '    "recv_time": "2023-07-13T15:15:27.4200000Z",\n'
#  '    "exchange_id": "DERIBIT",\n'
#  '    "symbol_id": "DERIBIT_OPT_BTC_USD_230714_30000_C",\n'
#  '    "metric_id": "GREEKS_RHO",\n'
# ...

# %%
import requests
url = 'https://rest.coinapi.io/v1/metrics/asset/ETH/current'
headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)


pprint(response.text)
# Out:
# '[]'

# %% [markdown]
# 6. Métrique Spécifique pour une crypto

# %%
import requests
url = 'https://rest.coinapi.io/v1/metrics/symbol/DERIBIT_OPT_BTC_USD_240329_80000_P/current'
headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)


pprint(response.text)
# Out:
# ('[\n'
#  '  {\n'
#  '    "entry_time": "2023-07-11T23:12:13.8555765Z",\n'
#  '    "recv_time": "2023-07-11T23:12:13.3440000Z",\n'
#  '    "exchange_id": "DERIBIT",\n'
#  '    "symbol_id": "DERIBIT_OPT_BTC_USD_240329_80000_P",\n'
#  '    "metric_id": "IV_BID",\n'
#  '    "value_decimal": 0\n'
#  '  },\n'
#  '  {\n'
#  '    "entry_time": "2023-07-11T23:12:13.8555765Z",\n'
#  '    "recv_time": "2023-07-11T23:12:13.3440000Z",\n'
#  '    "exchange_id": "DERIBIT",\n'
#  '    "symbol_id": "DERIBIT_OPT_BTC_USD_240329_80000_P",\n'
#  '    "metric_id": "DERIVATIVES_OPEN_INTEREST",\n'
#  '    "value_decimal": 0\n'
#  '  },\n'
#  '  {\n'
#  '    "entry_time": "2023-07-13T15:22:09.6510235Z",\n'
#  '    "recv_time": "2023-07-13T15:22:09.4280000Z",\n'
#  '    "exchange_id": "DERIBIT",\n'
#  '    "symbol_id": "DERIBIT_OPT_BTC_USD_240329_80000_P",\n'
#  '    "metric_id": "IV_ASK",\n'
#  '    "value_decimal": 499.29\n'
#  '  },\n'
#  '  {\n'
#  '    "entry_time": "2023-07-13T15:22:09.6510235Z",\n'
# ...

# %% [markdown]
# 7. Dernières données des échnagess

# %%
import requests

url = 'https://rest.coinapi.io/v1/ohlcv/BITSTAMP_SPOT_BTC_USD/latest?period_id=1MIN'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)


pprint(response.text)
# Out:
# ('[\n'
#  '  {\n'
#  '    "time_period_start": "2023-07-13T15:38:00.0000000Z",\n'
#  '    "time_period_end": "2023-07-13T15:39:00.0000000Z",\n'
#  '    "time_open": "2023-07-13T15:38:02.2510000Z",\n'
#  '    "time_close": "2023-07-13T15:38:13.9190000Z",\n'
#  '    "price_open": 30853,\n'
#  '    "price_high": 30855,\n'
#  '    "price_low": 30853,\n'
#  '    "price_close": 30855,\n'
#  '    "volume_traded": 0.39395917,\n'
#  '    "trades_count": 4\n'
#  '  },\n'
#  '  {\n'
#  '    "time_period_start": "2023-07-13T15:37:00.0000000Z",\n'
#  '    "time_period_end": "2023-07-13T15:38:00.0000000Z",\n'
#  '    "time_open": "2023-07-13T15:37:00.5960000Z",\n'
#  '    "time_close": "2023-07-13T15:37:59.3370000Z",\n'
#  '    "price_open": 30839,\n'
#  '    "price_high": 30882,\n'
#  '    "price_low": 30839,\n'
#  '    "price_close": 30854,\n'
#  '    "volume_traded": 1.07177485,\n'
#  '    "trades_count": 30\n'
#  '  },\n'
#  '  {\n'
# ...

# %% [markdown]
# 8. Données histriques

# %%
import requests

url = 'https://rest.coinapi.io/v1/ohlcv/BITSTAMP_SPOT_BTC_USD/history?period_id=1MIN&time_start=2023-07-01T00:00:00'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# ('[\n'
#  '  {\n'
#  '    "time_period_start": "2023-07-01T00:00:00.0000000Z",\n'
#  '    "time_period_end": "2023-07-01T00:01:00.0000000Z",\n'
#  '    "time_open": "2023-07-01T00:00:12.7540000Z",\n'
#  '    "time_close": "2023-07-01T00:00:54.5120000Z",\n'
#  '    "price_open": 30469,\n'
#  '    "price_high": 30478,\n'
#  '    "price_low": 30469,\n'
#  '    "price_close": 30478,\n'
#  '    "volume_traded": 0.15866675,\n'
#  '    "trades_count": 9\n'
#  '  },\n'
#  '  {\n'
#  '    "time_period_start": "2023-07-01T00:01:00.0000000Z",\n'
#  '    "time_period_end": "2023-07-01T00:02:00.0000000Z",\n'
#  '    "time_open": "2023-07-01T00:01:08.0490000Z",\n'
#  '    "time_close": "2023-07-01T00:01:48.5240000Z",\n'
#  '    "price_open": 30468,\n'
#  '    "price_high": 30468,\n'
#  '    "price_low": 30459,\n'
#  '    "price_close": 30459,\n'
#  '    "volume_traded": 0.2082518,\n'
#  '    "trades_count": 6\n'
#  '  },\n'
#  '  {\n'
# ...

# %% [markdown]
# 9. Dernières commandes

# %%
import requests
url = 'https://rest.coinapi.io/v1/orderbooks/BITSTAMP_SPOT_BTC_USD/latest'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  '      },\n'
#  '      {\n'
#  '        "price": 30581,\n'
#  '        "size": 3.93196233\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30580,\n'
#  '        "size": 0.00211001\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30576,\n'
#  '        "size": 0.0028138\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30575,\n'
#  '        "size": 2.8114\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30572,\n'
#  '        "size": 1.1228143\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30569,\n'
#  '        "size": 0.00211102\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30567,\n'
#  '        "size": 0.32714851\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30565,\n'
#  '        "size": 0.00281516\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30558,\n'
#  '        "size": 2.4983\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 30557,\n'
# ...

# %% [markdown]
# 10. historique des commandes

# %%
import requests
url = 'https://rest.coinapi.io/v1/orderbooks/BITSTAMP_SPOT_BTC_USD/history?time_start=2023-01-01T00:00:00'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  '      },\n'
#  '      {\n'
#  '        "price": 16469,\n'
#  '        "size": 3.62787692\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16468,\n'
#  '        "size": 0.02425972\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16467,\n'
#  '        "size": 0.01266063\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16463,\n'
#  '        "size": 7.4063343\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16455,\n'
#  '        "size": 0.00279572\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16453,\n'
#  '        "size": 28.55\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16451,\n'
#  '        "size": 12.3246\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16450,\n'
#  '        "size": 0.0015649\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16444,\n'
#  '        "size": 0.2\n'
#  '      },\n'
#  '      {\n'
#  '        "price": 16433,\n'
# ...

# %% [markdown]
# 11. Quotations en cours

# %%
import requests
url = 'https://rest.coinapi.io/v1/quotes/current'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  '    "bid_size": 2690.37038608,\n'
#  '    "last_trade": {\n'
#  '      "time_exchange": "2023-07-13T13:10:07.2750000Z",\n'
#  '      "time_coinapi": "2023-07-13T13:10:07.3824262Z",\n'
#  '      "uuid": "e09293d5-30f6-4112-bd1a-adb63442ef53",\n'
#  '      "price": 0.0394,\n'
#  '      "size": 380.71065989,\n'
#  '      "taker_side": "BUY"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "symbol_id": "BITBAY_SPOT_ZRX_PLN",\n'
#  '    "time_exchange": "2023-07-13T15:45:39.3260000Z",\n'
#  '    "time_coinapi": "2023-07-13T15:45:39.3962149Z",\n'
#  '    "ask_price": 0.88,\n'
#  '    "ask_size": 133.13636364,\n'
#  '    "bid_price": 0.85,\n'
#  '    "bid_size": 1269.5,\n'
#  '    "last_trade": {\n'
#  '      "time_exchange": "2023-07-13T15:45:39.3260000Z",\n'
#  '      "time_coinapi": "2023-07-13T15:45:39.4767809Z",\n'
#  '      "uuid": "999278b7-f5b4-456f-aaaa-b8156dd0d5aa",\n'
#  '      "price": 0.88,\n'
# ...

# %% [markdown]
# 12. Dernières quotations

# %%
import requests
url = 'https://rest.coinapi.io/v1/quotes/latest'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# ('[\n'
#  '  {\n'
#  '    "symbol_id": "BYBITSPOT_SPOT_SPELL_USDT",\n'
#  '    "time_exchange": "2023-07-13T16:03:31.2200000Z",\n'
#  '    "time_coinapi": "2023-07-13T16:03:31.3157579Z",\n'
#  '    "ask_price": 0.00049257,\n'
#  '    "ask_size": 169787.4,\n'
#  '    "bid_price": 0.00049105,\n'
#  '    "bid_size": 228006.9\n'
#  '  },\n'
#  '  {\n'
#  '    "symbol_id": "BYBITSPOT_SPOT_WOO_USDT",\n'
#  '    "time_exchange": "2023-07-13T16:03:31.2210000Z",\n'
#  '    "time_coinapi": "2023-07-13T16:03:31.3169874Z",\n'
#  '    "ask_price": 0.22934,\n'
#  '    "ask_size": 1452.48,\n'
#  '    "bid_price": 0.22838,\n'
#  '    "bid_size": 3890.29\n'
#  '  },\n'
#  '  {\n'
#  '    "symbol_id": "BYBITSPOT_SPOT_FTT_USDT",\n'
#  '    "time_exchange": "2023-07-13T16:03:31.2210000Z",\n'
#  '    "time_coinapi": "2023-07-13T16:03:31.3171286Z",\n'
#  '    "ask_price": 1.5386,\n'
#  '    "ask_size": 53.73,\n'
#  '    "bid_price": 1.5357,\n'
#  '    "bid_size": 9.175\n'
#  '  },\n'
#  '  {\n'
# ...

# %% [markdown]
# 13. Quotations historiques

# %%
import requests
url = 'https://rest.coinapi.io/v1/quotes/BITSTAMP_SPOT_BTC_USD/history?time_start=2023-01-01T00:00:00'

headers = {'X-CoinAPI-Key' : '3A5CEF16-7C99-4467-92EC-EA9431EAEDDE'}
response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# ('[\n'
#  '  {\n'
#  '    "symbol_id": "BITSTAMP_SPOT_BTC_USD",\n'
#  '    "time_exchange": "2023-01-01T00:00:00.8570000Z",\n'
#  '    "time_coinapi": "2023-01-01T00:00:00.8698512Z",\n'
#  '    "ask_price": 16531,\n'
#  '    "ask_size": 0.60419389,\n'
#  '    "bid_price": 16530,\n'
#  '    "bid_size": 0.50075688\n'
#  '  },\n'
#  '  {\n'
#  '    "symbol_id": "BITSTAMP_SPOT_BTC_USD",\n'
#  '    "time_exchange": "2023-01-01T00:00:10.7630000Z",\n'
#  '    "time_coinapi": "2023-01-01T00:00:10.7885884Z",\n'
#  '    "ask_price": 16531,\n'
#  '    "ask_size": 0.60419389,\n'
#  '    "bid_price": 16530,\n'
#  '    "bid_size": 0.00075688\n'
#  '  },\n'
#  '  {\n'
#  '    "symbol_id": "BITSTAMP_SPOT_BTC_USD",\n'
#  '    "time_exchange": "2023-01-01T00:00:12.6570000Z",\n'
#  '    "time_coinapi": "2023-01-01T00:00:12.6679801Z",\n'
#  '    "ask_price": 16530,\n'
#  '    "ask_size": 0.5,\n'
#  '    "bid_price": 16528,\n'
#  '    "bid_size": 0.5\n'
#  '  },\n'
#  '  {\n'
# ...
