# %%
# !pip install pyEX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 5.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.8 MB/s eta 0:00:00
# ...
#   Created wheel for sseclient: filename=sseclient-0.0.27-py3-none-any.whl size=5565 sha256=a2dac134f6c64f50b924a73c968c0ac3e97353a52b4c011dba500b2c3eaa866f
#   Stored in directory: /root/.cache/pip/wheels/60/57/0e/09b1264923280e935a34cc543b7f147f5df12490bd7a992f42
# Successfully built sseclient
# ...

# %%
import pyEX as p
import pandas as pd

# %%
cle_api = "sk_535ff593190b40c8b7414989bfaa53f9"

# %%
c = p.Client(api_token=cle_api)

# %%
sym = "AAPL"

d = c.chart(symbol=sym)

# %%
df = pd.DataFrame.from_dict(d)

df
# Out:
#      close     high       low     open   priceDate symbol     volume  \
# 0   189.59  190.070  188.9400  189.080  2023-06-29   AAPL   46347308
# 1   189.25  189.900  187.6000  187.930  2023-06-28   AAPL   51216801
# 2   188.06  188.390  185.6700  185.890  2023-06-27   AAPL   50730846
# 3   185.27  188.050  185.2300  186.830  2023-06-26   AAPL   48088661
# 4   186.68  187.560  185.0100  185.550  2023-06-23   AAPL   53116996
# 5   187.00  187.045  183.6700  183.740  2023-06-22   AAPL   51245327
# 6   183.96  185.410  182.5901  184.900  2023-06-21   AAPL   49515697
# 7   185.01  186.100  184.4100  184.410  2023-06-20   AAPL   49799092
# 8   184.92  186.990  184.2700  186.730  2023-06-16   AAPL  101256225
# 9   186.01  186.520  183.7800  183.960  2023-06-15   AAPL   65433166
# 10  183.95  184.390  182.0200  183.370  2023-06-14   AAPL   57462882
# 11  183.31  184.150  182.4400  182.800  2023-06-13   AAPL   54929129
# 12  183.79  183.890  180.9700  181.270  2023-06-12   AAPL   54754995
# ...
